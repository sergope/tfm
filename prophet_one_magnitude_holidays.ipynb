# %% [markdown]
# <a href="https://colab.research.google.com/github/sergope/tfm/blob/main/prophet_one_magnitude_holidays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Conectar el notebook con la cuenta de gdrive
from google.colab import drive
drive.mount('/content/drive/', force_remount=False)

BASE_FOLDER = 'drive/My Drive/TFM/resources/'
# Out:
# Mounted at /content/drive/

# %%
# %run 'drive/My Drive/TFM/prophet_functions'.ipynb
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
file_name = 'getafe'
magnitude = 8
periods = 7
options = {"holidays": True}

predict_one_magnitude(file_name, magnitude, periods, options)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# if entro
#              ds       yhat  yhat_lower  yhat_upper
# 2510 2020-01-03  88.690263   43.061289  132.097014
# 2511 2020-01-04  77.474564   32.302240  123.750386
# 2512 2020-01-05  72.035540   26.864870  119.000787
# 2513 2020-01-06  78.490842   30.237912  121.447645
# 2514 2020-01-07  90.213108   47.478728  133.724489
