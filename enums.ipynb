# %% [markdown]
# <a href="https://colab.research.google.com/github/sergope/tfm/blob/main/enums.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
estacion_de_medida = {
    'GETAFE': {
        'codigo_nacional': 28065014,
        'municipio': 65,
        'nombre': 'Getafe'
    }
}

# %%
magnitudes = {
    1: {
        'CODE': 'SO2',
        'DESCRIPCION': 'Dióxido de azufre',
        'CODIGO_TECNICA_MEDIDA': 38,
        'DESCRIPCION_TECNICA': 'Fluorescencia ultravioleta',
        'UNIDAD': 'μg/m³',
        'DESCRIPCION_UNIDAD': 'microgramos por metro cúbico'
    },
    6: {
        'DESCRIPCION': 'Monóxido de carbono',
        'CODIGO_TECNICA_MEDIDA': 48,
        'DESCRIPCION_TECNICA': 'Espectrometría infrarroja no dispersiva',
        'UNIDAD': 'mg/m³',
        'DESCRIPCION_UNIDAD': 'miligramos por metro cúbico'
    },
    7: {
        'DESCRIPCION': 'Monóxido de nitrógeno',
        'CODIGO_TECNICA_MEDIDA': 8,
        'DESCRIPCION_TECNICA': 'Quimioluminiscencia',
        'UNIDAD': 'μg/m³',
        'DESCRIPCION_UNIDAD': 'microgramos por metro cúbico'
    },
    8: {
        'CODE': 'N02',
        'DESCRIPCION': 'Dióxido de nitrógeno',
        'CODIGO_TECNICA_MEDIDA': 8,
        'DESCRIPCION_TECNICA': 'Quimioluminiscencia',
        'UNIDAD': 'μg/m³',
        'DESCRIPCION_UNIDAD': 'microgramos por metro cúbico'
    },
    9: {
        'CODE': 'PM2_2',
        'DESCRIPCION': 'Partículas en suspensión < PM2,5',
        'CODIGO_TECNICA_MEDIDA': 49,
        'DESCRIPCION_TECNICA': 'Absorción beta',
        'UNIDAD': 'μg/m³',
        'DESCRIPCION_UNIDAD': 'microgramos por metro cúbico'
    },
    10: {
        'CODE': 'PM10',
        'DESCRIPCION': 'Partículas en suspensión < PM10',
        'CODIGO_TECNICA_MEDIDA': 49,
        'DESCRIPCION_TECNICA': 'Absorción beta',
        'UNIDAD': 'μg/m³',
        'DESCRIPCION_UNIDAD': 'microgramos por metro cúbico'
    },
    12: {
        'DESCRIPCION': 'Óxidos de nitrógeno',
        'CODIGO_TECNICA_MEDIDA': 8,
        'DESCRIPCION_TECNICA': 'Quimioluminiscencia',
        'UNIDAD': 'μg/m³',
        'DESCRIPCION_UNIDAD': 'microgramos por metro cúbico'
    },
    14: {
        'CODE': 'O3',
        'DESCRIPCION': 'Ozono',
        'CODIGO_TECNICA_MEDIDA': 6,
        'DESCRIPCION_TECNICA': 'Absorción ultravioleta',
        'UNIDAD': 'μg/m³',
        'DESCRIPCION_UNIDAD': 'microgramos por metro cúbico'
    },
    20: {
        'DESCRIPCION': 'Tolueno',
        'CODIGO_TECNICA_MEDIDA': 59,
        'DESCRIPCION_TECNICA': 'Cromatografía de gases',
        'UNIDAD': 'μg/m³',
        'DESCRIPCION_UNIDAD': 'microgramos por metro cúbico'
    },
    22: {
        'DESCRIPCION': 'Black Carbon',
        'CODIGO_TECNICA_MEDIDA': 7,
        'DESCRIPCION_TECNICA': 'Absorción de luz',
        'UNIDAD': 'μg/m³',
        'DESCRIPCION_UNIDAD': 'microgramos por metro cúbico'
    },
    30: {
        'DESCRIPCION': 'Benceno',
        'CODIGO_TECNICA_MEDIDA': 59,
        'DESCRIPCION_TECNICA': 'Cromatografía de gases',
        'UNIDAD': 'μg/m³',
        'DESCRIPCION_UNIDAD': 'microgramos por metro cúbico'
    },
    42: {
        'DESCRIPCION': 'Hidrocarburos totales',
        'CODIGO_TECNICA_MEDIDA': 2,
        'DESCRIPCION_TECNICA': 'Ionización llama',
        'UNIDAD': 'mg/m³',
        'DESCRIPCION_UNIDAD': 'miligramos por metro cúbico'
    },
    44: {
        'DESCRIPCION': 'Hidrocarburos no metánicos',
        'CODIGO_TECNICA_MEDIDA': 2,
        'DESCRIPCION_TECNICA': 'Ionización llama',
        'UNIDAD': 'mg/m³',
        'DESCRIPCION_UNIDAD': 'miligramos por metro cúbico'
    },
    431: {
        'DESCRIPCION': 'MetaParaXileno',
        'CODIGO_TECNICA_MEDIDA': 59,
        'DESCRIPCION_TECNICA': 'Fluorescencia ultravioleta',
        'UNIDAD': 'μg/m³',
        'DESCRIPCION_UNIDAD': 'Cromatografía de gases'
    },

}

# %%
indice_contaminantes = {
    'PM2_5': {
        'DESCRIPCION': 'Partículas menos de 2.5 µm (PM2.5)',
        'MUY_BUENO': 10,
        'BUENO': 20,
        'REGULAR': 25,
        'MALO': 50,
        'MUY_MALO': 800
    },
    'PM10': {
        'DESCRIPCION': 'Partículas menos de 10 µm (PM10)',
        'MUY_BUENO': 20,
        'BUENO': 35,
        'REGULAR': 50,
        'MALO': 100,
        'MUY_MALO': 1200
    },
    'NO2': {
        'DESCRIPCION': 'Dióxido de Nitrógeno (NO2)',
        'MUY_BUENO': 40,
        'BUENO': 100,
        'REGULAR': 200,
        'MALO': 400,
        'MUY_MALO': 1000
    },
    'O3': {
        'DESCRIPCION': 'Ozono (O3)',
        'MUY_BUENO': 80,
        'BUENO': 120,
        'REGULAR': 180,
        'MALO': 240,
        'MUY_MALO': 600
    },
    'SO2': {
        'DESCRIPCION': 'Dióxido de Azufre (SO2)',
        'MUY_BUENO': 100,
        'BUENO': 200,
        'REGULAR': 350,
        'MALO': 500,
        'MUY_MALO': 1250
    }

}

# %% [markdown]
# CALIDAD DEL AIRE
# Índice de Calidad del Aire
# (basado en la concentración de los contaminantes en µg/m3)
# Contaminantes considerados
# Muy bueno
# Bueno
# Regular
# Malo
# Muy malo
# Partículas menos de 2.5 µm (PM2.5)
# 0-10
# 11-20
# 21-25
# 26-50
# 51-800
# Partículas menos de 10 µm (PM10)
# 0-20
# 21-35
# 36-50
# 51-100
# 101-1200
# Dióxido de Nitrógeno (NO2)
# 0-40
# 41-100
# 101-200
# 201-400
# 401-1000
# Ozono (O3)
# 0-80
# 81-120
# 121-180
# 181-240
# 241-600
# Dióxido de Azufre (SO2)
# 0-100
# 101-200
# 201-350
# 351-500
# 501-1250
